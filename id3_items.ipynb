# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('m_id/1.jpg')
img=cv2.resize(img, (640, 480))
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
kernel = np.ones((5,5),np.float32)/25
gray = cv2.filter2D(gray,-1,kernel)
edges = cv2.Canny(gray,400,600,apertureSize = 5)
plt.imshow(edges)
plt.show()

# %%
first_name = cv2.rectangle(img, (500, 100), (630, 180), (255, 0, 0), 2)
last_name = cv2.rectangle(img, (200, 180), (630, 220), (255, 0, 0), 2)
add = cv2.rectangle(img, (220, 220), (630, 350), (0, 0, 255), 2)
id_no = cv2.rectangle(img, (220, 350), (630, 450), (0, 255, 0), 2)
ocr = cv2.rectangle(img, (220, 100), (630, 450), (255, 255, 255), 2)

cv2.rectangle        
plt.imshow(img)
plt.show()

# %%
import easyocr

# %%
reader = easyocr.Reader(['ar'])
result = reader.readtext(last_name)
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [[[[383, 27], [471, 27], [471, 69], [383, 69]], 'زم', 0.3669131091906635],
#  [[[550, 136], [592, 136], [592, 160], [550, 160]], 'دما', 0.3969077031182899],
#  [[[366, 181], [600, 181], [600, 214], [366, 214]],
#   'ممدوح السيد السيد آدمد',
#   0.15278093063751108],
#  [[[433, 230], [604, 230], [604, 274], [433, 274]],
#   'المحروسة الجديدة',
#   0.7215361643872882],
#  [[[395, 273], [603, 273], [603, 311], [395, 311]],
#   'ثان الرمل - الاسكندرية',
#   0.7962884645779675],
#  [[[58, 438], [211, 438], [211, 470], [58, 470]],
#   '1[8285709',
#   0.8781180415720313]]
